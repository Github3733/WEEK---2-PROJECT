# %%
positions = ['G', 'G', 'G', '-', 'B', 'B', 'B']
print("[ 0 ,  1 ,  2 ,  3 ,  4 ,  5 ,  6 ]")
print(positions)


while True:
        pos = input("Enter the position of the frog you want to move (0-6), or 'q' to quit: ")

        if pos == 'q':
            print("Quitting the game.")
            break

        pos = int(pos)

        pos2 = 0

        if pos < 0 or pos > 6:
            print("Invalid Move.Please enter a valid position.")

        if positions[pos] == '-':
            print("Invalid Move.Please enter a valid position.")


        if positions[pos] == 'G':
            if pos + 1 <= 6 and positions[pos + 1] == '-':
                pos2 = pos
                positions[pos + 1] = 'G'
                positions[pos2] = '-'
            elif pos + 2 <= 6 and positions[pos + 2] == '-' and positions[pos + 1] == 'B':
                pos2 = pos
                positions[pos + 2] = 'G'
                positions[pos2] = '-'
            else:
                print("Invalid move")

        elif(positions[pos]=='B'):
            if(pos-1>=0 and positions[pos-1]=='-'):
                pos2=pos
                positions[pos-1] = 'B'
                positions[pos2] = '-'
            elif(pos-2>=0 and positions[pos-2]=='-' and positions[pos-1] =='G'):
                pos2=pos
                positions[pos-2]='B'
                positions[pos2] = '-'
            else:
                print("Invalid move")
                
        print("[ 0 ,  1 ,  2 ,  3 ,  4 ,  5 ,  6 ]")       
        print(positions)

        if positions == ['B','B','B','-','G','G','G']:
            print("HURRAY!!!!YOU WIN!!!!!")
            break

        elif positions == ['G','G','G','B','B','B','-']:
            print("YOU LOSE")
            break

        elif positions == ['-','G','G','G','B','B','B']:
            print("SORRY!!YOU LOST.BETTER LUCK NEXT TIME.")
            break

        elif positions == ['G','G','B','B','B','-','G']:
            print("SORRY!!YOU LOST.BETTER LUCK NEXT TIME.")
            break

        elif positions == ['B','-','G','G','G','B','B']:
            print("SORRY!!YOU LOST.BETTER LUCK NEXT TIME.")
            break
# Out:
# [ 0 ,  1 ,  2 ,  3 ,  4 ,  5 ,  6 ]
# ['G', 'G', 'G', '-', 'B', 'B', 'B']
# Enter the position of the frog you want to move (0-6), or 'q' to quit: 2
# [ 0 ,  1 ,  2 ,  3 ,  4 ,  5 ,  6 ]
# ['G', 'G', '-', 'G', 'B', 'B', 'B']
# Enter the position of the frog you want to move (0-6), or 'q' to quit: 4
# [ 0 ,  1 ,  2 ,  3 ,  4 ,  5 ,  6 ]
# ['G', 'G', 'B', 'G', '-', 'B', 'B']
# Enter the position of the frog you want to move (0-6), or 'q' to quit: 3
# [ 0 ,  1 ,  2 ,  3 ,  4 ,  5 ,  6 ]
# ['G', 'G', 'B', '-', 'G', 'B', 'B']
# Enter the position of the frog you want to move (0-6), or 'q' to quit: 5
# [ 0 ,  1 ,  2 ,  3 ,  4 ,  5 ,  6 ]
# ['G', 'G', 'B', 'B', 'G', '-', 'B']
# Enter the position of the frog you want to move (0-6), or 'q' to quit: 4
# [ 0 ,  1 ,  2 ,  3 ,  4 ,  5 ,  6 ]
# ['G', 'G', 'B', 'B', '-', 'G', 'B']
# Enter the position of the frog you want to move (0-6), or 'q' to quit: 6
# [ 0 ,  1 ,  2 ,  3 ,  4 ,  5 ,  6 ]
# ['G', 'G', 'B', 'B', 'B', 'G', '-']
# ...
